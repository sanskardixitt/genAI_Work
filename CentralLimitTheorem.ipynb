# %% [markdown]
# The **Central Limit Theorem (CLT)** states that if we take a large number of independent random samples from any population (regardless of its original distribution) and compute their sample means (averages), then the distribution of these means will approximate a normal (bell-shaped) distribution, as long as the sample size is sufficiently large.

# %% [markdown]
# When we perform a large number of independent random experiments and plot the probability distribution of outcomes, the resulting distribution often approximates a normal (bell-shaped) curve. This happens because probabilities of different outcomes follow structured patterns, and when we aggregate many trials, the shape naturally emerges due to the underlying statistical properties of the system.

# %% [markdown]
# # Code to Simulate 10 Coin Flips & Plot Probability Curve

# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of coin flips per experiment
n = 10

# Number of times we repeat the experiment (higher = smoother curve)
num_experiments = 10000

# Simulating the experiment
results = []
for _ in range(num_experiments):
    flips = np.random.choice([0, 1], size=n, p=[0.5, 0.5])  # 0 = Tails, 1 = Heads
    num_heads = np.sum(flips)  # Count the number of heads
    results.append(num_heads)

print("Simulated Results:")
print(results)

# Count occurrences of each possible number of heads (0 to 10)
values, counts = np.unique(results, return_counts=True)

# Convert counts to probabilities
probabilities = counts / num_experiments

# Plotting
plt.figure(figsize=(8, 5))
plt.bar(values, probabilities, color='lightcoral', edgecolor='black', alpha=0.7, label="Simulated Probabilities")
plt.plot(values, probabilities, 'o-', color='blue', label="Smooth Curve")  # Connecting dots for smoothness

# Labels and Title
plt.xlabel("Number of Heads in 10 Coin Flips")
plt.ylabel("Probability")
plt.title("Simulated Probability Distribution of Getting Heads in 10 Coin Flips")
plt.xticks(np.arange(0, n+1, 1))
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show Plot
plt.show()
# Out:
# Simulated Results:
# [5, 4, 3, 5, 6, 5, 5, 5, 5, 7, 4, 6, 0, 4, 4, 4, 7, 5, 5, 3, 5, 4, 7, 7, 3, 5, 4, 6, 7, 5, 4, 3, 5, 9, 7, 2, 5, 1, 5, 6, 4, 4, 6, 2, 5, 4, 3, 7, 6, 7, 3, 5, 4, 2, 8, 4, 5, 6, 4, 6, 4, 7, 4, 7, 5, 7, 6, 6, 4, 8, 6, 5, 5, 8, 1, 8, 2, 4, 9, 6, 4, 6, 6, 7, 6, 3, 4, 3, 6, 7, 4, 6, 5, 4, 6, 10, 6, 7, 5, 7, 3, 5, 3, 6, 4, 5, 8, 6, 6, 4, 10, 6, 4, 6, 6, 3, 7, 5, 5, 2, 6, 9, 6, 5, 7, 5, 6, 6, 3, 4, 5, 4, 4, 5, 6, 4, 7, 3, 5, 4, 5, 5, 7, 4, 3, 7, 8, 7, 6, 4, 7, 4, 5, 7, 5, 4, 4, 5, 3, 7, 3, 5, 6, 7, 6, 5, 9, 8, 2, 7, 5, 7, 4, 10, 6, 8, 7, 5, 4, 5, 7, 4, 5, 8, 2, 5, 6, 5, 3, 5, 7, 4, 5, 7, 4, 6, 7, 5, 5, 3, 4, 4, 5, 6, 5, 4, 3, 3, 3, 5, 7, 5, 5, 2, 7, 4, 4, 4, 6, 3, 5, 5, 7, 3, 6, 5, 4, 6, 6, 3, 4, 7, 5, 6, 5, 6, 3, 3, 4, 7, 5, 5, 7, 6, 4, 3, 4, 4, 3, 6, 4, 6, 2, 8, 3, 6, 3, 6, 1, 6, 5, 6, 3, 2, 4, 6, 7, 4, 5, 6, 4, 3, 3, 4, 1, 4, 5, 7, 2, 7, 3, 6, 4, 6,
# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of dice rolls per experiment
num_experiments = 10000

# Simulating the experiment
results = []
for _ in range(num_experiments):
    die1 = np.random.randint(1, 7)  # Roll first die (1 to 6)
    die2 = np.random.randint(1, 7)  # Roll second die (1 to 6)
    total = die1 + die2  # Sum of both dice
    results.append(total)

print("Simulated Results:")
print(results)

# Count occurrences of each possible sum (2 to 12)
values, counts = np.unique(results, return_counts=True)

# Convert counts to probabilities
probabilities = counts / num_experiments

# Plotting
plt.figure(figsize=(8, 5))
plt.bar(values, probabilities, color='orange', edgecolor='black', alpha=0.7, label="Simulated Probabilities")
plt.plot(values, probabilities, 'o-', color='blue', label="Smooth Curve")  # Connecting dots for smoothness

# Labels and Title
plt.xlabel("Sum of Two Dice Rolls")
plt.ylabel("Probability")
plt.title("Simulated Probability Distribution of Sum of Two Dice Rolls")
plt.xticks(np.arange(2, 13, 1))
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show Plot
plt.show()
# Out:
# Simulated Results:
# [12, 8, 7, 10, 11, 9, 12, 11, 6, 7, 10, 3, 8, 4, 10, 8, 6, 11, 10, 8, 3, 7, 3, 7, 7, 5, 8, 4, 6, 7, 8, 6, 7, 8, 9, 9, 5, 7, 8, 5, 9, 3, 5, 6, 9, 9, 4, 4, 9, 5, 10, 9, 9, 4, 2, 3, 9, 9, 5, 10, 4, 9, 6, 11, 10, 9, 6, 5, 3, 9, 3, 6, 7, 7, 9, 7, 8, 6, 8, 4, 8, 7, 11, 6, 10, 3, 9, 5, 5, 7, 4, 8, 9, 6, 9, 6, 6, 7, 6, 7, 11, 9, 5, 4, 11, 7, 6, 8, 7, 12, 9, 3, 2, 10, 7, 11, 5, 9, 10, 7, 6, 7, 10, 9, 10, 7, 9, 6, 7, 5, 7, 9, 9, 6, 11, 8, 3, 6, 5, 11, 7, 11, 11, 8, 6, 7, 3, 6, 4, 7, 6, 8, 6, 7, 7, 4, 7, 7, 6, 7, 9, 10, 4, 6, 4, 7, 4, 3, 8, 6, 7, 6, 8, 9, 7, 5, 4, 7, 9, 8, 10, 5, 11, 4, 8, 7, 9, 11, 3, 7, 5, 5, 4, 8, 5, 9, 7, 8, 4, 5, 4, 7, 5, 6, 9, 8, 12, 10, 11, 7, 3, 7, 7, 4, 12, 10, 9, 8, 7, 7, 6, 6, 7, 11, 5, 4, 6, 6, 8, 3, 10, 6, 6, 11, 4, 3, 4, 3, 6, 10, 7, 12, 10, 4, 6, 5, 9, 11, 6, 10, 5, 9, 2, 10, 10, 9, 9, 8, 11, 8, 8, 5, 6, 3, 7, 9, 8, 5, 5, 5, 10, 12, 7, 9, 7, 2, 5, 9, 6, 9, 6, 7, 9, 9, 9, 3, 4, 8, 9, 5, 8, 9, 6, 7, 10, 5, 2, 12, 9, 9, 7, 2, 4, 5, 7, 12, 4, 8, 9, 9, 4, 10, 10, 5, 12, 8, 11, 6, 6, 5, 11, 9, 8, 7, 5, 4, 6, 6, 7, 3, 4, 2, 4, 11, 5, 7, 7, 5, 11, 10, 4, 12, 6, 10, 9, 7, 5, 6, 8, 12, 11, 9, 12, 7, 3, 10, 8, 11, 7, 5, 5, 10, 3, 4, 8, 9, 7, 6, 8, 7, 3, 6, 3, 10, 6, 9, 3, 7, 8, 6, 5, 8, 10, 6, 8, 7, 5
7, 4, 7, 8, 5, 6, 10, 8, 5, 6, 8, 4, 6, 7, 7, 3, 7, 12, 7, 12, 7, 7, 5, 6, 11, 10, 11, 2, 4, 8, 5, 12, 7, 4, 8, 3, 11, 5, 6, 12, 8, 8, 9, 5, 10, 8, 7, 7, 9, 3, 7, 7, 5, 7, 7, 9, 10, 9, 8, 4, 6, 7, 4, 7, 12, 5, 10, 10, 5, 7, 5, 7, 11, 12, 6, 3, 7, 8, 7, 5, 11, 6, 5, 7, 8, 6, 7, 6, 8, 8, 4, 3, 10, 2, 4, 5, 10, 10, 8, 7, 5, 10, 5, 10, 5, 10, 7, 6, 10, 7, 5, 3, 7, 3, 5, 6, 7, 7, 5, 11, 9, 5, 2, 6, 7, 2, 8, 6, 6, 6, 11, 6, 2, 8, 9, 7, 5, 9, 6, 8, 7, 8, 3, 11, 5, 4, 10, 11, 9, 12, 5, 8, 7, 5, 2, 7, 7, 5, 7, 5, 5, 7, 2, 3, 7, 4, 9, 11, 7, 4, 10, 10, 5, 3, 7, 8, 4, 5, 4, 2, 8, 10, 7, 9, 11, 5, 5, 9, 3, 7, 5, 11, 3, 5, 6, 2, 4, 4, 7, 9, 2, 7, 5, 7, 6, 9, 7, 9, 7, 6, 9, 9, 7, 6, 11, 6, 8, 12, 3, 2, 4, 5, 8, 8, 3, 8, 10, 10, 3, 7, 4, 7, 6, 11, 6, 7, 11, 4, 4, 9, 9, 3, 8, 5, 7, 8, 4, 7, 7, 2, 8, 5, 4, 8, 7, 7, 10, 12, 3, 6, 9, 3, 8, 8, 4, 5, 7, 5, 7, 6, 3, 5, 3, 4, 8, 8, 10, 6, 7, 7, 7, 5, 4, 12, 7, 7, 7, 7, 6, 5, 9, 10, 10, 7, 11, 10, 3, 11, 6, 5, 2, 8, 2, 8, 7, 5, 9, 9, 6, 5, 3, 7, 9, 9, 7, 4, 5, 10, 4, 7, 4, 4, 4, 4, 5, 11, 9, 3, 5, 8, 7, 7, 9, 7, 10, 9, 5, 4, 6, 10, 5, 11, 5, 4, 4, 3, 10, 8, ...

# %% [markdown]
# # Dice Sum Using Probability Calculation

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sum of two dice (possible values: 2 to 12)
values = np.arange(2, 13)

# Theoretical probabilities based on counting combinations
probabilities = np.array([
    1/36,  # Sum = 2 (only 1+1)
    2/36,  # Sum = 3 (1+2, 2+1)
    3/36,  # Sum = 4 (1+3, 2+2, 3+1)
    4/36,  # Sum = 5 (1+4, 2+3, 3+2, 4+1)
    5/36,  # Sum = 6 (1+5, 2+4, 3+3, 4+2, 5+1)
    6/36,  # Sum = 7 (most common: 1+6, 2+5, 3+4, etc.)
    5/36,  # Sum = 8
    4/36,  # Sum = 9
    3/36,  # Sum = 10
    2/36,  # Sum = 11
    1/36   # Sum = 12 (only 6+6)
])

# Plotting
plt.figure(figsize=(8, 5))
plt.bar(values, probabilities, color='orange', edgecolor='black', alpha=0.7, label="Theoretical Probabilities")
plt.plot(values, probabilities, 'o-', color='blue', label="Smooth Curve")  # Connecting dots for smoothness

# Labels and Title
plt.xlabel("Sum of Two Dice Rolls")
plt.ylabel("Probability")
plt.title("Theoretical Probability Distribution of Sum of Two Dice Rolls")
plt.xticks(values)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show Plot
plt.show()
